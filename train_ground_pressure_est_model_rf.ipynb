# %%
import os, joblib
from utils.crane_dataset import CraneDataset
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
from skl2onnx import convert_sklearn
from skl2onnx.common.data_types import FloatTensorType

# %%
data_root_path = '.' + os.sep + 'data'
data_file_name_list = os.listdir(data_root_path)
data_file_name_list
# Out:
# ['safe-boom-40-swing-180-load-40-.csv',
#  'safe-boom-50-swing-180-load-50-.csv',
#  'safe-boom-60-swing-180-load-60-.csv',
#  'safe-boom-70-swing-180-load-100-.csv',
#  'safe-boom-80-swing-180-load-120-.csv',
#  'unsafe-swing-0-load-70-.csv',
#  'unsafe-swing-0-load-90-.csv',
#  'unsafe-swing-135-load-50-.csv',
#  'unsafe-swing-135-load-70-.csv',
#  'unsafe-swing-180-load-70-.csv',
#  'unsafe-swing-180-load-90-.csv',
#  'unsafe-swing-45-load-50-.csv',
#  'unsafe-swing-45-load-70-.csv',
#  'unsafe-swing-90-load-70-.csv',
#  'unsafe-swing-90-load-90-.csv']

# %%
dataset_inst = CraneDataset(file_path_list=data_file_name_list)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
dataset = dataset_inst.get_dataset()
dataset
# Out:
#        Time(sec)  Actual_Load_Left_1(N)  Actual_Load_Left_2(N)  \
# 0       2.000253              170062.47              180680.23
# 1       2.010253              169988.02              180641.70
# 2       2.020253              170243.17              180771.25
# 3       2.030253              170218.60              180761.86
# 4       2.040253              170446.06              180881.53
# ...          ...                    ...                    ...
# 60866  30.080253              466861.72              469939.30
# 60867  30.090253              467010.30              470228.10
# 60868  30.100253              467125.65              470500.43
# 60869  30.110253              467204.29              470754.94
# 60870  30.120253              467243.03              470991.39
#
#        Actual_Load_Left_3(N)  Actual_Load_Left_4(N)  Actual_Load_Left_5(N)  \
# 0                  191420.21              202263.13              213189.69
# 1                  191418.53              202299.00              213263.63
# 2                  191419.30              202168.53              213000.13
# 3                  191425.46              202190.51              213038.14
# 4                  191434.63              202087.07              212820.55
# ...                      ...                    ...                    ...
# 60866              472885.15              475696.30              478369.78
# 60867              473300.71              476224.68              478996.60
# 60868              473714.28              476763.24              479643.31
# 60869              474126.27              477313.61              480312.29
# 60870              474538.75              477879.60              481008.39
#
#        Actual_Load_Right_1(N)  Actual_Load_Right_2(N)  Actual_Load_Right_3(N)  \
# 0                 168664.7200             179283.9400             190028.3600
# 1                 168592.2200             179247.3300             190028.5700
# 2                 168843.8000             179373.4500             190025.9800
# 3                 168805.8100             179350.5400             190018.5600
# 4                 169013.4300             179450.3900             190007.9100
# ...                       ...                     ...                     ...
# 60866               2391.8443               4189.5085               6463.6691
# 60867               2036.8146               3778.6999               6029.9405
# 60868               1692.7003               3370.7405               5595.7670
# 60869               1362.3229               2966.2656               5160.4804
# 60870               1048.5416               2564.9751               4721.8324
#
#        Actual_Load_Right_4(N)  Actual_Load_Right_5(N)  Boom_Angle(deg)  \
# 0                 200878.5800              211815.210        66.879271
# 1                 200916.3500              211891.060        66.850415
# 2                 200782.5100              211624.140        66.821450
# 3                 200790.8900              211648.560        66.792379
# 4                 200667.6000              211411.080        66.763200
# ...                       ...                     ...              ...
# 60866               9200.0780               12384.487        54.638893
# 60867               8774.9342               11998.079        54.593906
# 60868               8350.5832               11617.992        54.548922
# 60869               7925.8818               11243.384        54.503942
# 60870               7497.7710               10871.448        54.458966
#
#        Swing_Angle(deg)  Load(Ton)
# 0          1.560000e-30       40.0
# 1         -4.820000e-30       40.0
# 2          3.790000e-30       40.0
# 3          3.020000e-30       40.0
# 4         -2.210000e-30       40.0
# ...                 ...        ...
# 60866      9.000000e+01       90.0
# 60867      9.000000e+01       90.0
# 60868      9.000000e+01       90.0
# 60869      9.000000e+01       90.0
# 60870      9.000000e+01       90.0
#
# [60871 rows x 14 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60871 entries, 0 to 60870
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Time(sec)               60871 non-null  float64
#  1   Actual_Load_Left_1(N)   60871 non-null  float64
#  2   Actual_Load_Left_2(N)   60871 non-null  float64
#  3   Actual_Load_Left_3(N)   60871 non-null  float64
#  4   Actual_Load_Left_4(N)   60871 non-null  float64
#  5   Actual_Load_Left_5(N)   60871 non-null  float64
#  6   Actual_Load_Right_1(N)  60871 non-null  float64
#  7   Actual_Load_Right_2(N)  60871 non-null  float64
#  8   Actual_Load_Right_3(N)  60871 non-null  float64
#  9   Actual_Load_Right_4(N)  60871 non-null  float64
#  10  Actual_Load_Right_5(N)  60871 non-null  float64
#  11  Boom_Angle(deg)         60871 non-null  float64
#  12  Swing_Angle(deg)        60871 non-null  float64
#  13  Load(Ton)               60871 non-null  float64
# dtypes: float64(14)
# memory usage: 6.5 MB

# %%
train_data = dataset_inst.get_train_dataset()
train_data
# Out:
#        Boom_Angle(deg)  Swing_Angle(deg)  Load(Ton)  Actual_Load_Left_1(N)  \
# 0            66.850415     -4.820000e-30       40.0              169988.02
# 1            66.821450      3.790000e-30       40.0              170243.17
# 2            66.792379      3.020000e-30       40.0              170218.60
# 3            66.763200     -2.210000e-30       40.0              170446.06
# 4            66.704524     -1.680000e-30       40.0              170674.74
# ...                ...               ...        ...                    ...
# 48691        54.728875      9.000000e+01       90.0              466481.30
# 48692        54.638893      9.000000e+01       90.0              466861.72
# 48693        54.593906      9.000000e+01       90.0              467010.30
# 48694        54.548922      9.000000e+01       90.0              467125.65
# 48695        54.503942      9.000000e+01       90.0              467204.29
#
#        Actual_Load_Left_2(N)  Actual_Load_Left_3(N)  Actual_Load_Left_4(N)  \
# 0                  180641.70              191418.53              202299.00
# 1                  180771.25              191419.30              202168.53
# 2                  180761.86              191425.46              202190.51
# 3                  180881.53              191434.63              202087.07
# 4                  181013.04              191466.52              202017.40
# ...                      ...                    ...                    ...
# 48691              469322.21              472052.91              474671.10
# 48692              469939.30              472885.15              475696.30
# 48693              470228.10              473300.71              476224.68
# 48694              470500.43              473714.28              476763.24
# 48695              470754.94              474126.27              477313.61
#
#        Actual_Load_Left_5(N)  Actual_Load_Right_1(N)  Actual_Load_Right_2(N)  \
# 0                  213263.63             168592.2200             179247.3300
# 1                  213000.13             168843.8000             179373.4500
# 2                  213038.14             168805.8100             179350.5400
# 3                  212820.55             169013.4300             179450.3900
# 4                  212647.90             169176.5800             179516.1300
# ...                      ...                     ...                     ...
# 48691              477174.50               3122.6348               5013.5356
# 48692              478369.78               2391.8443               4189.5085
# 48693              478996.60               2036.8146               3778.6999
# 48694              479643.31               1692.7003               3370.7405
# 48695              480312.29               1362.3229               2966.2656
#
#        Actual_Load_Right_3(N)  Actual_Load_Right_4(N)  Actual_Load_Right_5(N)
# 0                 190028.5700             200916.3500              211891.060
# 1                 190025.9800             200782.5100              211624.140
# 2                 190018.5600             200790.8900              211648.560
# 3                 190007.9100             200667.6000              211411.080
# 4                 189973.8600             200531.9000              211172.370
# ...                       ...                     ...                     ...
# 48691               7326.9701              10050.8310               13173.012
# 48692               6463.6691               9200.0780               12384.487
# 48693               6029.9405               8774.9342               11998.079
# 48694               5595.7670               8350.5832               11617.992
# 48695               5160.4804               7925.8818               11243.384
#
# [48696 rows x 13 columns]

# %%
val_data = dataset_inst.get_val_dataset()
val_data
# Out:
#        Boom_Angle(deg)  Swing_Angle(deg)  Load(Ton)  Actual_Load_Left_1(N)  \
# 0            66.879271      1.560000e-30       40.0              170062.47
# 1            66.733915      9.370000e-31       40.0              170483.87
# 2            66.585904      9.870000e-30       40.0              171219.98
# 3            66.435284      3.480000e-30       40.0              172178.57
# 4            66.282099     -4.470000e-31       40.0              173074.62
# ...                ...               ...        ...                    ...
# 12170        55.358831      9.000000e+01       90.0              462051.33
# 12171        55.133860      9.000000e+01       90.0              463830.77
# 12172        54.908862      9.000000e+01       90.0              465449.65
# 12173        54.683882      9.000000e+01       90.0              466684.16
# 12174        54.458966      9.000000e+01       90.0              467243.03
#
#        Actual_Load_Left_2(N)  Actual_Load_Left_3(N)  Actual_Load_Left_4(N)  \
# 0                  180680.23              191420.21              202263.13
# 1                  180907.70              191448.84              202089.07
# 2                  181343.90              191577.62              201904.46
# 3                  181932.53              191787.34              201728.12
# 4                  182509.08              192036.91              201644.70
# ...                      ...                    ...                    ...
# 12170              464014.70              465933.24              467806.33
# 12171              466038.10              468185.27              470271.32
# 12172              467946.52              470361.77              472693.91
# 12173              469636.63              472468.95              475178.49
# 12174              470991.39              474538.75              477879.60
#
#        Actual_Load_Left_5(N)  Actual_Load_Right_1(N)  Actual_Load_Right_2(N)  \
# 0                  213189.69             168664.7200             179283.9400
# 1                  212810.14             169022.0200             179447.1800
# 2                  212307.76             169498.5900             179622.9100
# 3                  211740.01             170040.2700             179793.3400
# 4                  211319.02             170443.4100             179875.6600
# ...                      ...                     ...                     ...
# 12170              469633.33               8792.9026              11045.4470
# 12171              472295.30               6649.9670               8816.9263
# 12172              474941.47               4647.1116               6681.1238
# 12173              477762.68               2754.5771               4601.4865
# 12174              481008.39               1048.5416               2564.9751
#
#        Actual_Load_Right_3(N)  Actual_Load_Right_4(N)  Actual_Load_Right_5(N)
# 0                 190028.3600             200878.5800              211815.210
# 1                 189992.6500             200640.0800              211371.150
# 2                 189860.3000             200194.0100              210607.250
# 3                 189650.9900             199598.2500              209620.160
# 4                 189405.5600             199019.5700              208704.160
# ...                       ...                     ...                     ...
# 12170              13535.4500              16257.2530               19205.198
# 12171              11268.6360              13997.9220               16997.608
# 12172               9061.7776              11779.7840               14825.853
# 12173               6896.1467               9625.4635               12776.343
# 12174               4721.8324               7497.7710               10871.448
#
# [12175 rows x 13 columns]

# %%
model = RandomForestRegressor(n_estimators=10, random_state=0, n_jobs=os.cpu_count())
model.fit(dataset_inst.get_train_dataset_for_model()[dataset_inst.get_model_feature_names()], 
          dataset_inst.get_train_dataset_for_model()[dataset_inst.get_model_target_names()])
# Out:
# RandomForestRegressor(n_estimators=10, n_jobs=8, random_state=0)

# %%
pred_out = model.predict(dataset_inst.get_val_dataset_for_model()[dataset_inst.get_model_feature_names()])
pred_target_names = ['Pred_Load_Left_1(N)', 'Pred_Load_Left_2(N)', 'Pred_Load_Left_3(N)', 'Pred_Load_Left_4(N)', 'Pred_Load_Left_5(N)',
                     'Pred_Load_Right_1(N)', 'Pred_Load_Right_2(N)', 'Pred_Load_Right_3(N)', 'Pred_Load_Right_4(N)', 'Pred_Load_Right_5(N)']

target_pred = pd.DataFrame(pred_out, columns=pred_target_names)

# %%
absolute_error_names = ['Absolute_Error_Left_1(%)', 'Absolute_Error_Left_2(%)', 'Absolute_Error_Left_3(%)', 'Absolute_Error_Left_4(%)', 'Absolute_Error_Left_5(%)',
                        'Absolute_Error_Right_1(%)', 'Absolute_Error_Right_2(%)', 'Absolute_Error_Right_3(%)', 'Absolute_Error_Right_4(%)', 'Absolute_Error_Right_5(%)']

relative_error_names = ['Relative_Error_Left_1(%)', 'Relative_Error_Left_2(%)', 'Relative_Error_Left_3(%)', 'Relative_Error_Left_4(%)', 'Relative_Error_Left_5(%)',
                        'Relative_Error_Right_1(%)', 'Relative_Error_Right_2(%)', 'Relative_Error_Right_3(%)', 'Relative_Error_Right_4(%)', 'Relative_Error_Right_5(%)']

actual_load = val_data[dataset_inst.get_data_target_names()].to_numpy()
pred_load = target_pred.to_numpy()

absolute_error = pd.DataFrame(abs(actual_load-pred_load), columns=absolute_error_names)
relative_error = pd.DataFrame((abs(actual_load-pred_load)/abs(actual_load))*100, columns=relative_error_names)
result = pd.concat([val_data, target_pred, absolute_error, relative_error], axis=1)

result.describe()
# Out:
#        Boom_Angle(deg)  Swing_Angle(deg)     Load(Ton)  Actual_Load_Left_1(N)  \
# count     12175.000000      1.217500e+04  12175.000000           12175.000000
# mean         63.520530      8.060977e+01     70.671047          280420.008592
# std          11.369928      6.067786e+01     23.783388          110252.169601
# min          40.000000     -3.180000e-28     40.000000            1351.487900
# 25%          59.460772      2.449026e+01     50.000000          205512.070000
# 50%          70.000000      7.574472e+01     70.000000          298398.750000
# 75%          70.000000      1.350000e+02     90.000000          358767.815000
# max          80.000000      1.800000e+02    120.000000          493019.530000
#
#        Actual_Load_Left_2(N)  Actual_Load_Left_3(N)  Actual_Load_Left_4(N)  \
# count           12175.000000           12175.000000           12175.000000
# mean           270239.083296          258122.330067          245833.398274
# std             71306.393845           49564.991274           74177.162316
# min             66400.622000          182590.050000           69831.394000
# 25%            214880.465000          214803.955000          191082.420000
# 50%            276248.910000          253963.040000          249802.650000
# 75%            314003.340000          283763.430000          297335.065000
# max            470991.390000          474538.750000          477879.600000
#
#        Actual_Load_Left_5(N)  Actual_Load_Right_1(N)  Actual_Load_Right_2(N)  \
# count           12175.000000            12175.000000            12175.000000
# mean           235135.937374           208889.004659           195573.684626
# std            113706.098285           109508.564461            67417.641354
# min              1380.030800             1038.630700             2564.975100
# 25%            147007.710000           115725.100000           144689.940000
# 50%            227857.440000           206677.930000           197477.600000
# 75%            327901.890000           294826.955000           238508.795000
# max            489313.250000           492176.150000           392850.990000
#
#        ...  Relative_Error_Left_1(%)  Relative_Error_Left_2(%)  \
# count  ...              1.217500e+04              1.217500e+04
# mean   ...              4.573995e-01              3.401180e-01
# std    ...              1.062899e+00              7.732662e-01
# min    ...              2.866178e-07              3.234412e-07
# 25%    ...              1.510945e-02              9.118567e-03
# 50%    ...              5.099143e-02              3.065399e-02
# 75%    ...              2.897671e-01              2.383697e-01
# max    ...              2.057640e+01              1.289467e+01
#
#        Relative_Error_Left_3(%)  Relative_Error_Left_4(%)  \
# count              12175.000000              1.217500e+04
# mean                   0.285308              4.080203e-01
# std                    0.632280              8.120523e-01
# min                    0.000003              5.340467e-07
# 25%                    0.004597              8.348353e-03
# 50%                    0.015767              3.162056e-02
# 75%                    0.188721              3.913114e-01
# max                   10.577979              1.066342e+01
#
#        Relative_Error_Left_5(%)  Relative_Error_Right_1(%)  \
# count              12175.000000               12175.000000
# mean                   0.719929                   0.651381
# std                    1.678449                   1.486570
# min                    0.000003                   0.000000
# 25%                    0.014252                   0.019616
# 50%                    0.061963                   0.071244
# 75%                    0.680518                   0.542405
# max                   38.562538                  49.327595
#
#        Relative_Error_Right_2(%)  Relative_Error_Right_3(%)  \
# count               12175.000000               12175.000000
# mean                    0.474835                   0.402675
# std                     1.018494                   0.906481
# min                     0.000000                   0.000000
# 25%                     0.012074                   0.006672
# 50%                     0.041213                   0.022263
# 75%                     0.409478                   0.269952
# max                    25.158362                  14.812926
#
#        Relative_Error_Right_4(%)  Relative_Error_Right_5(%)
# count               1.217500e+04               12175.000000
# mean                5.692903e-01                   1.011804
# std                 1.309648e+00                   2.422191
# min                 1.174761e-14                   0.000005
# 25%                 1.334232e-02                   0.022736
# 50%                 4.909729e-02                   0.096671
# 75%                 3.901718e-01                   0.685086
# max                 1.767975e+01                  37.215117
#
# [8 rows x 43 columns]

# %%
joblib.dump(model, 'rf_model.joblib')
# Out:
# ['rf_model.joblib']

# %%
# Convert to ONNX format
initial_type = [('float_input', FloatTensorType([None, 3]))]
onnx_model = convert_sklearn(model, initial_types=initial_type)

# Save the ONNX model to a file
onnx_model_path = "rf_model.onnx"
with open(onnx_model_path, "wb") as f:
    f.write(onnx_model.SerializeToString())
