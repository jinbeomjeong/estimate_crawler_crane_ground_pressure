# %%
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense

# %%
# 사전 학습할 모델 구성
model = Sequential()
model.add(LSTM(100, input_shape=(30, 10)))
model.add(Dense(1))  # 출력층

model.compile(optimizer='adam', loss='mse')

# %%
x_train = np.random.rand(100, 30, 10)
y_train = np.random.rand(100, 1)

# %%
model.fit(x_train, y_train, epochs=200, batch_size=100)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.2581
# Epoch 2/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1299
# Epoch 3/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0893
# Epoch 4/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1117
# Epoch 5/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1313
# Epoch 6/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1245
# Epoch 7/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1079
# Epoch 8/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0946
# Epoch 9/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0886
# Epoch 10/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0888
# Epoch 11/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0922
# Epoch 12/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0959
# ...

# %%
pred = model.predict(x_train)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
y_train
# Out:
# array([[9.32869638e-02],
#        [2.27171493e-01],
#        [6.73819566e-01],
#        [5.91419325e-01],
#        [2.43213139e-01],
#        [7.30943806e-01],
#        [3.97000897e-01],
#        [5.41664250e-01],
#        [7.52209745e-01],
#        [3.20957951e-01],
#        [1.09846372e-01],
#        [3.25745603e-01],
#        [7.47143343e-01],
#        [3.73857523e-01],
#        [1.32459746e-01],
#        [3.53975172e-01],
#        [6.47199255e-01],
#        [1.24508241e-01],
#        [9.17484599e-01],
#        [2.25510336e-01],
#        [9.31186131e-01],
#        [1.66169069e-01],
#        [6.12654682e-02],
#        [1.22980211e-02],
#        [5.25681499e-01],
#        [3.86704783e-01],
#        [9.62440925e-01],
#        [6.19329072e-01],
#        [2.89612657e-01],
#        [6.53035091e-01],
#        [6.06607039e-01],
#        [4.96132608e-01],
#        [3.83411665e-01],
#        [9.97163370e-01],
#        [2.68918300e-01],
#        [4.43685794e-01],
#        [3.71886214e-02],
# ...

# %%
(abs(pred-y_train)/y_train)*100
# Out:
# array([[3.52808331e+02],
#        [2.55106100e+01],
#        [3.84574664e+00],
#        [1.10374315e+01],
#        [9.70820120e+01],
#        [1.04064837e+01],
#        [3.28671010e+01],
#        [1.43179776e+01],
#        [1.75956255e+01],
#        [3.73515686e+01],
#        [6.75074062e+01],
#        [2.05882648e+01],
#        [1.86804228e+01],
#        [4.54117604e+01],
#        [3.90814233e+02],
#        [4.39798784e+01],
#        [2.18505271e+01],
#        [2.73955878e+02],
#        [3.15911629e+01],
#        [7.06718620e+01],
#        [3.50485194e+01],
#        [3.12716699e+01],
#        [7.06924414e+02],
#        [8.04106350e+02],
#        [4.31079027e+00],
#        [4.33892914e+01],
#        [2.94803549e+01],
#        [7.91292349e+00],
#        [6.25275802e+00],
#        [3.90994384e+00],
#        [3.28308450e+01],
#        [6.68832763e+00],
#        [1.06039378e+01],
#        [2.94579835e+01],
#        [5.49081707e+01],
#        [8.46811231e+00],
#        [1.14693821e+03],
# ...

# %%
new_model = Sequential()

for layer in model.layers[:-1]:  # 출력층 제외
    new_model.add(layer)

# %%
new_model.layers

# %%
for layer in new_model.layers:
    layer.trainable = False

# %%
new_model.layers

# %%
new_model.add(Dense(1, activation='linear'))

# %%
new_model.layers
